# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist


import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# # Load The Dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %% [markdown]
# # Display images

# %%
digit = 9
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap='gray_r')

        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Normalize Data(0-1)

# %%
x_train= x_train.astype("float32") / 255.0
x_test= x_test.astype("float32") / 255.0

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
digit = 9
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %% [markdown]
# # Model

# %%
model = keras.Sequential([
    keras.Input(shape=(28,28)),
    layers.Flatten(),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 235,146 (918.54 KB)
#  Trainable params: 235,146 (918.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Compile the model

# %%
#Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Train the model

# %%
#Train the model
h=model.fit(x=x_train, y=y_train, epochs=10, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8607 - loss: 0.4840 - val_accuracy: 0.9580 - val_loss: 0.1440
# Epoch 2/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9675 - loss: 0.1064 - val_accuracy: 0.9703 - val_loss: 0.1018
# Epoch 3/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9792 - loss: 0.0645 - val_accuracy: 0.9701 - val_loss: 0.0998
# Epoch 4/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9863 - loss: 0.0442 - val_accuracy: 0.9751 - val_loss: 0.0916
# Epoch 5/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9906 - loss: 0.0306 - val_accuracy: 0.9729 - val_loss: 0.0941
# Epoch 6/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9921 - loss: 0.0259 - val_accuracy: 0.9732 - val_loss: 0.1023
# Epoch 7/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9736 - val_loss: 0.1019
# Epoch 8/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9940 - loss: 0.0171 - val_accuracy: 0.9753 - val_loss: 0.0994
# Epoch 9/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9954 - loss: 0.0131 - val_accuracy: 0.9750 - val_loss: 0.1112
# Epoch 10/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.9759 - val_loss: 0.1077

# %%
#Evaluate the model on the test dataset
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9731 - loss: 0.1121
#
# Test accuracy: 0.9761999845504761

# %% [markdown]
# # Make predictions on the entire test images

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
#model.save("mnist_model_new1.h5")

# %%
ROWS = 5
COLS = 20

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model.predict(sample_images)

i = 0

plt.figure(figsize=(20,5))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i])
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# # Save the Model

# %%
model.save("mnist_NN_model.keras")
